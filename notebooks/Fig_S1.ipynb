# %%
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np

# %%
path_in = '../data/'
path_output = '../figures/'

# %%
ds_gs = xr.open_dataset(path_in + 'GS_along_track_spec.nc')
ds_agulhas = xr.open_dataset(path_in + 'Agulhas_along_track_spec.nc')
ds_ccs = xr.open_dataset(path_in + 'CCS_along_track_spec.nc')
ds_acc1 = xr.open_dataset(path_in + 'ACC1_along_track_spec.nc')
ds_acc2 = xr.open_dataset(path_in + 'ACC2_along_track_spec.nc')
ds_med = xr.open_dataset(path_in + 'MED_along_track_spec.nc')


ds_spec_oi = xr.open_dataset(path_in + 'spec_filtering.nc')

# %%
props = dict(boxstyle='round', facecolor='w')

# %%
fac = (2*np.pi)/1000
scale_oi = 20 # in km
fig, axes = plt.subplots(ncols = 6, figsize = (9, 3), sharey = True)
ax = axes[0]
ax.loglog(ds_gs.wavenumber/fac, ds_gs.spec_raw * fac, label = 'L3 product')
ax.loglog(ds_gs.wavenumber/fac, ds_gs.spec_oi * fac, label = 'Interpolated SWOT')
ax.plot([1/scale_oi, 1/scale_oi], [10**(-10), 30**1], 'k')
ax.set_ylim([np.amin(ds_gs.spec_oi * fac), np.amax(ds_gs.spec_oi * fac)])
ax.set_xlim([1/300, 1/3])
ax.set_ylim([10**(-10), 30**1])
ax.set_title('Gulf Stream')
ax.grid(visible=True, which='major', color='k', linestyle='-', alpha = .4)
ax.grid(visible=True, which='minor', color='k', linestyle='--', alpha = .2)
fig.legend(bbox_to_anchor=[.25, 1.15])
ax.text(0.82, 0.92, '(d)',
     transform = ax.transAxes, bbox = props, fontsize = 8)


ax = axes[1]
ax.loglog(ds_agulhas.wavenumber/fac, ds_agulhas.spec_raw * fac)
ax.loglog(ds_agulhas.wavenumber/fac, ds_agulhas.spec_oi * fac)
ax.plot([1/scale_oi, 1/scale_oi], [10**(-10), 30**1], 'k')
ax.set_ylim([np.amin(ds_agulhas.spec_oi * fac), np.amax(ds_agulhas.spec_oi * fac)])
ax.set_xlim([1/300, 1/3])
ax.set_ylim([10**(-10), 30**1])
ax.set_title('Agulhas')
ax.grid(visible=True, which='major', color='k', linestyle='-', alpha = .4)
ax.grid(visible=True, which='minor', color='k', linestyle='--', alpha = .2)
ax.text(0.82, 0.92, '(e)',
     transform = ax.transAxes, bbox = props, fontsize = 8)


ax = axes[2]
ax.loglog(ds_ccs.wavenumber/fac, ds_ccs.spec_raw * fac)
ax.loglog(ds_ccs.wavenumber/fac, ds_ccs.spec_oi * fac)
ax.plot([1/scale_oi, 1/scale_oi], [10**(-10), 30**1], 'k')
ax.set_ylim([np.amin(ds_ccs.spec_oi * fac), np.amax(ds_ccs.spec_oi * fac)])
ax.set_xlim([1/300, 1/2])
ax.set_ylim([10**(-10), 30**1])
ax.set_title('CCS')
ax.grid(visible=True, which='major', color='k', linestyle='-', alpha = .4)
ax.grid(visible=True, which='minor', color='k', linestyle='--', alpha = .2)
ax.text(0.82, 0.92, '(f)',
     transform = ax.transAxes, bbox = props, fontsize = 8)


ax = axes[3]
ax.loglog(ds_acc1.wavenumber/fac, ds_acc1.spec_raw * fac)
ax.loglog(ds_acc1.wavenumber/fac, ds_acc1.spec_oi * fac)
ax.plot([1/scale_oi, 1/scale_oi], [10**(-10), 30**1], 'k')
ax.set_ylim([np.amin(ds_acc1.spec_oi * fac), np.amax(ds_acc1.spec_oi * fac)])
ax.set_xlim([1/300, 1/3])
ax.set_ylim([10**(-10), 30**1])
ax.set_title('ACC1')
ax.grid(visible=True, which='major', color='k', linestyle='-', alpha = .4)
ax.grid(visible=True, which='minor', color='k', linestyle='--', alpha = .2)
ax.text(0.82, 0.92, '(g)',
     transform = ax.transAxes, bbox = props, fontsize = 8)

ax = axes[4]
ax.loglog(ds_acc2.wavenumber/fac, ds_acc2.spec_raw * fac)
ax.loglog(ds_acc2.wavenumber/fac, ds_acc2.spec_oi * fac)
ax.plot([1/scale_oi, 1/scale_oi], [10**(-10), 30**1], 'k')
ax.set_ylim([np.amin(ds_acc2.spec_oi * fac), np.amax(ds_acc2.spec_oi * fac)])
ax.set_xlim([1/300, 1/3])
ax.set_ylim([10**(-10), 30**1])
ax.set_title('ACC2')
ax.grid(visible=True, which='major', color='k', linestyle='-', alpha = .4)
ax.grid(visible=True, which='minor', color='k', linestyle='--', alpha = .2)
ax.text(0.82, 0.92, '(h)',
     transform = ax.transAxes, bbox = props, fontsize = 8)


ax = axes[5]
ax.loglog(ds_med.wavenumber/fac, ds_med.spec_raw * fac)
ax.loglog(ds_med.wavenumber/fac, ds_med.spec_oi * fac)
ax.plot([1/scale_oi, 1/scale_oi], [10**(-10), 30**1], 'k')
ax.set_ylim([np.amin(ds_med.spec_oi * fac), np.amax(ds_med.spec_oi * fac)])
ax.set_xlim([1/300, 1/3])
ax.set_ylim([10**(-10), 30**1])
ax.set_title('MED')
ax.grid(visible=True, which='major', color='k', linestyle='-', alpha = .4)
ax.grid(visible=True, which='minor', color='k', linestyle='--', alpha = .2)
ax.text(0.82, 0.92, '(i)',
     transform = ax.transAxes, bbox = props, fontsize = 8)


fig.supxlabel('Wavenumber [cpkm]')
fig.supylabel('PSD [$m^{2}/cpkm]$')

plt.tight_layout()
ax_inset1 = fig.add_axes([.68, 1.2, .12, .5])
ax_inset1.pcolormesh(ds_gs.longitude, ds_gs.latitude, ds_gs.ssha_raw, cmap = 'RdBu_r')
ax_inset1.set_title('SWOT L3')
ax_inset1.set_xlabel('Longitude [$^{\circ}$E]')
ax_inset1.set_ylabel('Latitude [$^{\circ}$N]')
ax_inset1.text(0.12, 0.88, '(b)',
     transform = ax_inset1.transAxes, bbox = props, fontsize = 8)



ax_inset2 = fig.add_axes([.85, 1.2, .13, .5])
p1 = ax_inset2.pcolormesh(ds_gs.longitude, ds_gs.latitude, ds_gs.ssha_oi, cmap = 'RdBu_r')
ax_inset2.set_title('Interpolated')
ax_inset2.set_xlabel('Longitude [$^{\circ}$E]')
plt.colorbar(p1, ax = ax_inset2, label = 'SSHA [m]')

ax_inset2.text(0.12, 0.88, '(c)',
     transform = ax_inset2.transAxes, bbox = props, fontsize = 8)




ax_inset3 = fig.add_axes([.25, 1.3, .3, .4])
# ax_inset3bis = fig.add_axes([.37, 1.3, .25, .4])



ax_inset3.loglog(ds_spec_oi.wavenumbers, ds_spec_oi.raw, color = 'saddlebrown', label = 'raw-SWOT')
ax_inset3.loglog(ds_spec_oi.wavenumbers, ds_spec_oi.lc15, color = 'peru', label = 'Parzen 15 km-SWOT')
ax_inset3.loglog(ds_spec_oi.wavenumbers, ds_spec_oi.lc30, color = 'darkorange', label = 'Parzen 30 km-SWOT')
ax_inset3.loglog(ds_spec_oi.wavenumbers, ds_spec_oi.lc50, color = 'tan', label = 'Parzen 50 km-SWOT')
ax_inset3.loglog(ds_spec_oi.wavenumbers, ds_spec_oi.oi, color = 'gold', label = 'OI-SWOT')
# ax_inset3.legend()
ax_inset3.set_xlabel('Wavenumber [cpkm]')
ax_inset3.set_ylabel('PSD [m$^{2}$/cpkm]')
ax_inset3.grid(True, which="both", alpha=0.3)
ax_inset3.text(0.9, 0.88, '(a)',
     transform = ax_inset3.transAxes, bbox = props, fontsize = 8)





ax_inset3.legend(fontsize = 6.5, loc = 3)
plt.tight_layout()
# plt.savefig(path_output + 'Fig_S1.png', dpi = 300, bbox_inches = 'tight')
# Out:
# <>:95: SyntaxWarning: invalid escape sequence '\c'
# <>:96: SyntaxWarning: invalid escape sequence '\c'
# <>:105: SyntaxWarning: invalid escape sequence '\c'
# <>:95: SyntaxWarning: invalid escape sequence '\c'
# <>:96: SyntaxWarning: invalid escape sequence '\c'
# <>:105: SyntaxWarning: invalid escape sequence '\c'
# /var/folders/bx/gz6w8d_533x2h1m1pq2pt88m0000gn/T/ipykernel_81827/3388040455.py:95: SyntaxWarning: invalid escape sequence '\c'
#   ax_inset1.set_xlabel('Longitude [$^{\circ}$E]')
# /var/folders/bx/gz6w8d_533x2h1m1pq2pt88m0000gn/T/ipykernel_81827/3388040455.py:96: SyntaxWarning: invalid escape sequence '\c'
#   ax_inset1.set_ylabel('Latitude [$^{\circ}$N]')
# /var/folders/bx/gz6w8d_533x2h1m1pq2pt88m0000gn/T/ipykernel_81827/3388040455.py:105: SyntaxWarning: invalid escape sequence '\c'
#   ax_inset2.set_xlabel('Longitude [$^{\circ}$E]')
# ...
