# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

# %%
path_in = '../data/'
path_output = '../figures/'

# %%
ds_ameda_biharmonic = xr.open_dataset(path_in + 'DYNED_SWOT_GS2_biharmonic.nc')
ds_ameda_biharmonic_filtered = xr.open_dataset(path_in + 'DYNED_SWOT_GS2_biharmonic_filtered.nc')


ds_ameda_duacs = xr.open_dataset(path_in + 'DYNED_GS2_SWOT_on_DUACS.nc')
field_swot_like = xr.open_dataset(path_in + 'cropped_duacs_swot_like.nc')
field_duacs_crop = xr.open_dataset(path_in + 'cropped_duacs.nc')

# %%
date_chosen = field_duacs_crop.time.values

id_eddy_duacs = np.where(ds_ameda_duacs.time.values == date_chosen)[0]
id_eddy_swot = np.where(ds_ameda_biharmonic.time.values == date_chosen)[0]
id_eddy_swot_filtered = np.where(ds_ameda_biharmonic_filtered.time.values == date_chosen)[0]

# %%
fig, ax = plt.subplots()
(field_swot_like.ssha).plot(ax = ax, vmin = -.8, vmax = .8, alpha = .4, cmap = 'RdBu_r', add_colorbar = False)
p1 = plt.pcolormesh(field_duacs_crop.lon, field_duacs_crop.lat, field_duacs_crop.zeta, vmin = -.8, vmax = .8, cmap = 'RdBu_r')
cax = fig.add_axes([.8, .3, 0.02, .3])
plt.colorbar(p1, cax = cax, label = 'SSHA [m]')
for eddy in id_eddy_duacs:
    
    ax.plot(ds_ameda_duacs.x_max[eddy, :], ds_ameda_duacs.y_max[eddy, :], color = 'k')

for eddy in id_eddy_swot:
    
    ax.plot(ds_ameda_biharmonic.x_max[eddy, :], ds_ameda_biharmonic.y_max[eddy, :], color = 'r', linestyle = '--')

ax.plot([], [], color = 'r', linestyle = '--', label = 'All AMEDA-SWOT')
ax.plot([], [], color = 'r', label = 'Filtered AMEDA-SWOT')

ax.plot([], [], color = 'k', label = 'All cropped-DUACS')
props = dict(boxstyle='round', facecolor='w', alpha=1)

ax.text(-65.2, 31, 'SWOT-like', rotation = 77, bbox = props)
ax.text(-64, 31, 'cropped-DUACS', rotation = 77, bbox = props)

for eddy in id_eddy_swot_filtered:
    ax.plot(ds_ameda_biharmonic_filtered.x_max[eddy, :], ds_ameda_biharmonic_filtered.y_max[eddy, :], color = 'r')
ax.legend(bbox_to_anchor = (.8, 1))
ax.set_ylim([30, 40])
ax.set_xlim([-66, -58])
ax.set_aspect('equal', 'box')
ax.set_title('')
plt.savefig(path_output + 'Fig_S3.png', dpi = 300, bbox_inches = 'tight')
