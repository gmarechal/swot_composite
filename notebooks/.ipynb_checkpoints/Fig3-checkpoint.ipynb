# %%
import warnings
warnings.filterwarnings('ignore')
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

# %%
path_in = '../data/'
path_output = '../figures/'

# %%
theta = np.linspace(0, 2*np.pi, 100)
x_circle = np.cos(theta)
y_circle = np.sin(theta)

x_circle_small = np.cos(theta)/2.5
y_circle_small = np.sin(theta)/2.5


arrow_length = 0.8  # Adjust length as needed
x_start = 0
y_start = 0
theta_rot = 0
x_end = x_start + arrow_length * np.cos(theta_rot*(+1))
y_end = y_start + arrow_length * np.sin(theta_rot*(+1))

props = dict(boxstyle='round', facecolor='w', alpha=1)
props1 = dict(boxstyle='round', facecolor='w', alpha=1)

n_quiver = 15


def plot_composite(ax, compo_2D, vmin, vmax, cmap0):
    p1 = ax.pcolormesh(compo_2D.x, compo_2D.y,  compo_2D, vmin = vmin, vmax = vmax, cmap = cmap0)
    ax.plot(x_circle, y_circle, color = 'k', linewidth = 2)
    ax.plot(x_circle, y_circle, color = 'w', linewidth = .5, linestyle = '--')
    ax.set_xticks([-1, -.4, 0, .4, 1], ['-2.5$R_{max}$', '-$R_{max}$', '0', '$R_{max}$', '2.5$R_{max}$'], rotation = 90)
    ax.set_yticks([-1, -.4, 0, .4, 1], ['-2.5$R_{max}$', '-$R_{max}$', '0', '$R_{max}$', '2.5$R_{max}$'])

    
    ax.plot(x_circle_small, y_circle_small, color = 'k', linewidth = 2)
    ax.plot(x_circle_small, y_circle_small, color = 'w', linewidth = .5)
    ax.plot(x_circle, y_circle, color = 'k', linewidth = 2)
    ax.plot(x_circle, y_circle, color = 'w', linewidth = .5, linestyle = '--')

    return p1

# %%
###########
# --- GS2
###########



ds_GS_cyc = xr.open_dataset(path_in + 'composite_swot_GS2_cyclonic_biharmonic.nc')
ds_GS_anticyc = xr.open_dataset(path_in + 'composite_swot_GS2_anticyclonic_biharmonic.nc')


VORT_GS_cyc = ds_GS_cyc.composite[0,:,:]
VORT_GS_anticyc = ds_GS_anticyc.composite[0,:,:]


ds_GS_cyc_swot_like = xr.open_dataset(path_in + 'composite_swot_like_GS2_cyclonic_biharmonic.nc')
ds_GS_anticyc_swot_like = xr.open_dataset(path_in + 'composite_swot_like_GS2_anticyclonic_biharmonic.nc')



VORT_GS_cyc_swot_like = ds_GS_cyc_swot_like.composite[1,:,:]
VORT_GS_anticyc_swot_like = ds_GS_anticyc_swot_like.composite[1,:,:]



# ###########
# # --- AGULHAS
# ###########
ds_AGULHAS_cyc = xr.open_dataset(path_in + 'composite_swot_AGULHAS_cyclonic_biharmonic.nc')
ds_AGULHAS_anticyc = xr.open_dataset(path_in + 'composite_swot_AGULHAS_anticyclonic_biharmonic.nc')


VORT_AGULHAS_cyc = ds_AGULHAS_cyc.composite[1,:,:]
VORT_AGULHAS_anticyc = ds_AGULHAS_anticyc.composite[1,:,:]



ds_AGUHAS_cyc_swot_like = xr.open_dataset(path_in + 'composite_swot_like_AGULHAS_cyclonic_biharmonic.nc')
ds_AGUHAS_anticyc_swot_like = xr.open_dataset(path_in + 'composite_swot_like_AGULHAS_anticyclonic_biharmonic.nc')



VORT_AGUHAS_cyc_swot_like = ds_AGUHAS_cyc_swot_like.composite[1,:,:]
VORT_AGUHAS_anticyc_swot_like = ds_AGUHAS_anticyc_swot_like.composite[1,:,:]




# ###########
# # --- CCS
# ###########


ds_CCS_cyc = xr.open_dataset(path_in + 'composite_swot_CCS_cyclonic_biharmonic.nc')
ds_CCS_anticyc = xr.open_dataset(path_in + 'composite_swot_CCS_anticyclonic_biharmonic.nc')


VORT_CCS_cyc = ds_CCS_cyc.composite[1,:,:]
VORT_CCS_anticyc = ds_CCS_anticyc.composite[1,:,:]


ds_CCS_cyc_swot_like = xr.open_dataset(path_in + 'composite_swot_like_CCS_cyclonic_biharmonic.nc')
ds_CCS_anticyc_swot_like = xr.open_dataset(path_in + 'composite_swot_like_CCS_anticyclonic_biharmonic.nc')



VORT_CCS_cyc_swot_like = ds_CCS_cyc_swot_like.composite[1,:,:]
VORT_CCS_anticyc_swot_like = ds_CCS_anticyc_swot_like.composite[1,:,:]




# ###########
# # --- ACC-1
# ###########

ds_ACC1_cyc = xr.open_dataset(path_in + 'composite_swot_ACC1_bis_cyclonic_biharmonic.nc')
ds_ACC1_anticyc = xr.open_dataset(path_in + 'composite_swot_ACC1_bis_anticyclonic_biharmonic.nc')


VORT_ACC1_cyc = ds_ACC1_cyc.composite[1,:,:]
VORT_ACC1_anticyc = ds_ACC1_anticyc.composite[1,:,:]


ds_ACC1_cyc_swot_like = xr.open_dataset(path_in + 'composite_swot_like_ACC1_bis_cyclonic_biharmonic.nc')
ds_ACC1_anticyc_swot_like = xr.open_dataset(path_in + 'composite_swot_like_ACC1_bis_anticyclonic_biharmonic.nc')



VORT_ACC1_cyc_swot_like = ds_ACC1_cyc_swot_like.composite[1,:,:]
VORT_ACC1_anticyc_swot_like = ds_ACC1_anticyc_swot_like.composite[1,:,:]


# ###########
# # --- ACC-2
# ###########



ds_ACC2_cyc = xr.open_dataset(path_in + 'composite_swot_ACC2_cyclonic_biharmonic.nc')
ds_ACC2_anticyc = xr.open_dataset(path_in + 'composite_swot_ACC2_anticyclonic_biharmonic.nc')


VORT_ACC2_cyc = ds_ACC2_cyc.composite[1,:,:]
VORT_ACC2_anticyc = ds_ACC2_anticyc.composite[1,:,:]

ds_ACC2_cyc_swot_like = xr.open_dataset(path_in + 'composite_swot_like_ACC2_cyclonic_biharmonic.nc')
ds_ACC2_anticyc_swot_like = xr.open_dataset(path_in + 'composite_swot_like_ACC2_anticyclonic_biharmonic.nc')




VORT_ACC2_cyc_swot_like = ds_ACC2_cyc_swot_like.composite[1,:,:]
VORT_ACC2_anticyc_swot_like = ds_ACC2_anticyc_swot_like.composite[1,:,:]



# ###########
# # --- MED
# ###########
ds_MED_cyc = xr.open_dataset(path_in + 'composite_swot_MED_cyclonic_biharmonic.nc')
ds_MED_anticyc = xr.open_dataset(path_in + 'composite_swot_MED_anticyclonic_biharmonic.nc')
KE_MED_cyc = ds_MED_cyc.composite[0,:,:]
KE_MED_anticyc = ds_MED_anticyc.composite[0,:,:]

VORT_MED_cyc = ds_MED_cyc.composite[1,:,:]
VORT_MED_anticyc = ds_MED_anticyc.composite[1,:,:]


ds_MED_cyc_swot_like = xr.open_dataset(path_in + 'composite_swot_like_MED_cyclonic_biharmonic.nc')
ds_MED_anticyc_swot_like = xr.open_dataset(path_in + 'composite_swot_like_MED_anticyclonic_biharmonic.nc')



VORT_MED_cyc_swot_like = ds_MED_cyc_swot_like.composite[1,:,:]
VORT_MED_anticyc_swot_like = ds_MED_anticyc_swot_like.composite[1,:,:]

# %%
omega = 7.2921e-5
# latitudes
lat_GS2 = 33
lat_AGULHAS = -36.5
lat_CCS = 37
lat_ACC1 = -50.5
lat_ACC2 = -57.5
lat_MED = 38.7

# Coriolis parameters

f_GS2 = 2 * omega* np.sin(np.deg2rad(lat_GS2))
f_AGULHAS = 2 * omega* np.sin(np.deg2rad(lat_AGULHAS))
f_CCS = 2 * omega* np.sin(np.deg2rad(lat_CCS))
f_ACC1 = 2 * omega* np.sin(np.deg2rad(lat_ACC1))
f_ACC2 = 2 * omega* np.sin(np.deg2rad(lat_ACC2))
f_MED = 2 * omega* np.sin(np.deg2rad(lat_MED))

# %%
perc_cyc = ['+137%', '110%', '+133%', '62%', '+80%', '+87%']
perc_anticy = ['+163%', '80%', '+147%', '36%', '+102%', '+56%']

# %%
fig, axes = plt.subplots(ncols = 6, nrows = 4, sharex = True, sharey = True)
vmin = -.5
vmax = .5
nb_quiver = 33
ax = axes[0][0]

ax.set_title('Gulf\nStream')

p1 = plot_composite(ax, VORT_GS_cyc/f_GS2, vmin, vmax, 'RdBu_r')
ax.text(0.38, 0.1, perc_cyc[0],
     transform = ax.transAxes, bbox = props, color = 'tomato', fontsize = 8)

ax = axes[1][0]
_ = plot_composite(ax, VORT_GS_cyc_swot_like/f_GS2, vmin, vmax, 'RdBu_r')

ax = axes[2][0]
_ = plot_composite(ax, VORT_GS_anticyc/f_GS2, vmin, vmax, 'RdBu_r')
ax.text(0.35, 0.1, perc_anticy[0],
     transform = ax.transAxes, bbox = props, color = 'teal', fontsize = 8)

ax = axes[3][0]
_ = plot_composite(ax, VORT_GS_anticyc_swot_like/f_GS2, vmin, vmax, 'RdBu_r')







ax = axes[0][1]

ax.set_title('Agulhas')
p1 = plot_composite(ax, VORT_AGULHAS_cyc/f_AGULHAS, vmin, vmax, 'RdBu_r')
ax.text(0.45, 0.1, perc_cyc[1],
     transform = ax.transAxes, bbox = props, color = 'tomato', fontsize = 8)

ax = axes[1][1]
_ = plot_composite(ax, VORT_AGUHAS_cyc_swot_like/f_AGULHAS, vmin, vmax, 'RdBu_r')


ax = axes[2][1]
_ = plot_composite(ax, VORT_AGULHAS_anticyc/f_AGULHAS, vmin, vmax, 'RdBu_r')
ax.text(0.55, 0.1, perc_anticy[1],
     transform = ax.transAxes, bbox = props, color = 'teal', fontsize = 8)

ax = axes[3][1]
_ = plot_composite(ax, VORT_AGUHAS_anticyc_swot_like/f_AGULHAS, vmin, vmax, 'RdBu_r')




ax = axes[0][2]

ax.set_title('CCS')
# ax.pcolormesh(ds_GS2_DUACS_cyclonic.x, ds_GS2_DUACS_cyclonic.y, uspeed_GS2_cyclonic, vmin = 0, vmax = .4)
p1= plot_composite(ax, VORT_CCS_cyc/f_CCS, vmin, vmax, 'RdBu_r')
ax.text(0.38, 0.1, perc_cyc[2],
     transform = ax.transAxes, bbox = props, color = 'tomato', fontsize = 8)

ax = axes[1][2]
_ = plot_composite(ax, VORT_CCS_cyc_swot_like/f_CCS, vmin, vmax, 'RdBu_r')

ax = axes[2][2]
_ = plot_composite(ax, VORT_CCS_anticyc/f_CCS, vmin, vmax, 'RdBu_r')
ax.text(0.35, 0.1, perc_anticy[2],
     transform = ax.transAxes, bbox = props, color = 'teal', fontsize = 8)

ax = axes[3][2]
_ = plot_composite(ax, VORT_CCS_anticyc_swot_like/f_CCS, vmin, vmax, 'RdBu_r')




ax = axes[0][3]

ax.set_title('ACC1')
# ax.pcolormesh(ds_GS2_DUACS_cyclonic.x, ds_GS2_DUACS_cyclonic.y, uspeed_GS2_cyclonic, vmin = 0, vmax = .4)
p1 = plot_composite(ax, VORT_ACC1_cyc/f_ACC1, vmin, vmax, 'RdBu_r')
ax.text(0.55, 0.1, perc_cyc[3],
     transform = ax.transAxes, bbox = props, color = 'tomato', fontsize = 8)

ax = axes[1][3]
_ = plot_composite(ax, VORT_ACC1_cyc_swot_like/f_ACC1, vmin, vmax, 'RdBu_r')

ax = axes[2][3]
_ = plot_composite(ax, VORT_ACC1_anticyc/f_ACC1, vmin, vmax, 'RdBu_r')
ax.text(0.55, 0.1, perc_anticy[3],
     transform = ax.transAxes, bbox = props, color = 'teal', fontsize = 8)


ax = axes[3][3]
_ = plot_composite(ax,  VORT_ACC1_anticyc_swot_like/f_ACC1, vmin, vmax, 'RdBu_r')






ax = axes[0][4]

ax.set_title('ACC2')
# ax.pcolormesh(ds_GS2_DUACS_cyclonic.x, ds_GS2_DUACS_cyclonic.y, uspeed_GS2_cyclonic, vmin = 0, vmax = .4)
p1 = plot_composite(ax, VORT_ACC2_cyc/f_ACC2,  vmin, vmax,  'RdBu_r')
ax.text(0.5, 0.1, perc_cyc[4],
     transform = ax.transAxes, bbox = props, color = 'tomato', fontsize = 8)

ax = axes[1][4]
_ = plot_composite(ax, VORT_ACC2_cyc_swot_like/f_ACC2,  vmin, vmax,  'RdBu_r')


ax = axes[2][4]
_ = plot_composite(ax, VORT_ACC2_anticyc/f_ACC2,  vmin, vmax,  'RdBu_r')
ax.text(0.35, 0.1, perc_anticy[4],
     transform = ax.transAxes, bbox = props, color = 'teal', fontsize = 8)


ax = axes[3][4]
_ = plot_composite(ax, VORT_ACC2_anticyc_swot_like/f_ACC2, vmin, vmax,  'RdBu_r')






ax = axes[0][5]

ax.set_title('MED')
# ax.pcolormesh(ds_GS2_DUACS_cyclonic.x, ds_GS2_DUACS_cyclonic.y, uspeed_GS2_cyclonic, vmin = 0, vmax = .4)
p1 = plot_composite(ax, VORT_MED_cyc/f_MED,  vmin, vmax,  'RdBu_r')
ax.text(0.45, 0.1, perc_cyc[5],
     transform = ax.transAxes, bbox = props, color = 'tomato', fontsize = 8)


ax = axes[1][5]
_ = plot_composite(ax, VORT_MED_cyc_swot_like/f_MED,  vmin, vmax,  'RdBu_r')


ax = axes[2][5]
_ = plot_composite(ax, VORT_MED_anticyc/f_MED,  vmin, vmax,  'RdBu_r')
ax.text(0.45, 0.1, perc_anticy[5],
     transform = ax.transAxes, bbox = props, color = 'teal', fontsize = 8)


ax = axes[3][5]
_ = plot_composite(ax, VORT_MED_anticyc_swot_like/f_MED, vmin, vmax,  'RdBu_r')




# cbar.ax.set_xticklabels(clevs1[::1] rotation=90)
cax = fig.add_axes([.26, 1.05, .5, 0.02])
cbar = plt.colorbar(p1, cax = cax, orientation = 'horizontal', extend = 'both')
cbar.ax.set_title('$\\frac{\\zeta}{f}$ []' ,fontsize = 15)
ax.text(-17, -.1, 'SWOT-like')
ax.text(-17, 2.4, 'SWOT')
ax.text(-17, 4.7, 'SWOT-like')
ax.text(-17, 7.2, 'SWOT')

ax.text(1.5, 0, 'Anticyclonic', rotation = 90, fontsize = 14)
ax.text(1.5, 5.3, 'Cyclonic', rotation = 90, fontsize = 14)

plt.savefig(path_output +'Fig3.png', dpi = 300, bbox_inches = 'tight')
