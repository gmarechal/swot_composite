# %%
import warnings
warnings.filterwarnings('ignore')
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

# %%
path_in = '../data/'
path_output = '../figures/'

# %%
theta = np.linspace(0, 2*np.pi, 100)
x_circle = np.cos(theta)
y_circle = np.sin(theta)

x_circle_small = np.cos(theta)/2.5
y_circle_small = np.sin(theta)/2.5


arrow_length = 0.8  # Adjust length as needed
x_start = 0
y_start = 0
theta_rot = 0
x_end = x_start + arrow_length * np.cos(theta_rot*(+1))
y_end = y_start + arrow_length * np.sin(theta_rot*(+1))

props1 = dict(boxstyle='round', facecolor='w', alpha=1)
n_quiver = 15


def plot_composite(ax, compo_2D, vmin, vmax, cmap0):
    p1 = ax.pcolormesh(compo_2D.x, compo_2D.y,  compo_2D, vmin = vmin, vmax = vmax, cmap = cmap0)
    ax.plot(x_circle, y_circle, color = 'k', linewidth = 2)
    ax.plot(x_circle, y_circle, color = 'w', linewidth = .5, linestyle = '--')
    ax.set_xticks([-1, -.4, 0, .4, 1], ['-2.5$R_{max}$', '-$R_{max}$', '0', '$R_{max}$', '2.5$R_{max}$'], rotation = 90)
    ax.set_yticks([-1, -.4, 0, .4, 1], ['-2.5$R_{max}$', '-$R_{max}$', '0', '$R_{max}$', '2.5$R_{max}$'])

    
    ax.plot(x_circle_small, y_circle_small, color = 'k', linewidth = 2)
    ax.plot(x_circle_small, y_circle_small, color = 'w', linewidth = .5)
    ax.plot(x_circle, y_circle, color = 'k', linewidth = 2)
    ax.plot(x_circle, y_circle, color = 'w', linewidth = .5, linestyle = '--')

    return p1

# %%
perc_cyc = ['+4%', '-4%', '+27%', '-6%', '+25%', '+29%']
perc_anticy = ['+8%', '-27%', '+24%', '-19%', '+38%', '+20%']

# %%
###########
# --- GS2
###########


ds_GS_cyc = xr.open_dataset(path_in + 'composite_swot_GS2_cyclonic_biharmonic.nc')
ds_GS_anticyc = xr.open_dataset(path_in + 'composite_swot_GS2_anticyclonic_biharmonic.nc')
KE_GS_cyc = ds_GS_cyc.composite[1,:,:]
KE_GS_anticyc = ds_GS_anticyc.composite[1,:,:]



ds_GS_cyc_swot_like = xr.open_dataset(path_in + 'composite_swot_like_GS2_cyclonic_biharmonic.nc')
ds_GS_anticyc_swot_like = xr.open_dataset(path_in + 'composite_swot_like_GS2_anticyclonic_biharmonic.nc')


KE_GS_cyc_swot_like = ds_GS_cyc_swot_like.composite[0,:,:]
KE_GS_anticyc_swot_like = ds_GS_anticyc_swot_like.composite[0,:,:]




# ###########
# # --- AGULHAS
# ###########
ds_AGULHAS_cyc = xr.open_dataset(path_in + 'composite_swot_AGULHAS_cyclonic_biharmonic.nc')
ds_AGULHAS_anticyc = xr.open_dataset(path_in + 'composite_swot_AGULHAS_anticyclonic_biharmonic.nc')
KE_AGULHAS_cyc = ds_AGULHAS_cyc.composite[0,:,:]
KE_AGULHAS_anticyc = ds_AGULHAS_anticyc.composite[0,:,:]




ds_AGUHAS_cyc_swot_like = xr.open_dataset(path_in + 'composite_swot_like_AGULHAS_cyclonic_biharmonic.nc')
ds_AGUHAS_anticyc_swot_like = xr.open_dataset(path_in + 'composite_swot_like_AGULHAS_anticyclonic_biharmonic.nc')


KE_AGUHAS_cyc_swot_like = ds_AGUHAS_cyc_swot_like.composite[0,:,:]
KE_AGUHAS_anticyc_swot_like = ds_AGUHAS_anticyc_swot_like.composite[0,:,:]





# ###########
# # --- CCS
# ###########


ds_CCS_cyc = xr.open_dataset(path_in + 'composite_swot_CCS_cyclonic_biharmonic.nc')
ds_CCS_anticyc = xr.open_dataset(path_in + 'composite_swot_CCS_anticyclonic_biharmonic.nc')
KE_CCS_cyc = ds_CCS_cyc.composite[0,:,:]
KE_CCS_anticyc = ds_CCS_anticyc.composite[0,:,:]



ds_CCS_cyc_swot_like = xr.open_dataset(path_in + 'composite_swot_like_CCS_cyclonic_biharmonic.nc')
ds_CCS_anticyc_swot_like = xr.open_dataset(path_in + 'composite_swot_like_CCS_anticyclonic_biharmonic.nc')


KE_CCS_cyc_swot_like = ds_CCS_cyc_swot_like.composite[0,:,:]
KE_CCS_anticyc_swot_like = ds_CCS_anticyc_swot_like.composite[0,:,:]





# ###########
# # --- ACC-1
# ###########

ds_ACC1_cyc = xr.open_dataset(path_in + 'composite_swot_ACC1_bis_cyclonic_biharmonic.nc')
ds_ACC1_anticyc = xr.open_dataset(path_in + 'composite_swot_ACC1_bis_anticyclonic_biharmonic.nc')
KE_ACC1_cyc = ds_ACC1_cyc.composite[0,:,:]
KE_ACC1_anticyc = ds_ACC1_anticyc.composite[0,:,:]



ds_ACC1_cyc_swot_like = xr.open_dataset(path_in + 'composite_swot_like_ACC1_bis_cyclonic_biharmonic.nc')
ds_ACC1_anticyc_swot_like = xr.open_dataset(path_in + 'composite_swot_like_ACC1_bis_anticyclonic_biharmonic.nc')


KE_ACC1_cyc_swot_like = ds_ACC1_cyc_swot_like.composite[0,:,:]
KE_ACC1_anticyc_swot_like = ds_ACC1_anticyc_swot_like.composite[0,:,:]



# ###########
# # --- ACC-2
# ###########



ds_ACC2_cyc = xr.open_dataset(path_in + 'composite_swot_ACC2_cyclonic_biharmonic.nc')
ds_ACC2_anticyc = xr.open_dataset(path_in + 'composite_swot_ACC2_anticyclonic_biharmonic.nc')
KE_ACC2_cyc = ds_ACC2_cyc.composite[0,:,:]
KE_ACC2_anticyc = ds_ACC2_anticyc.composite[0,:,:]

VORT_ACC2_cyc = ds_ACC2_cyc.composite[1,:,:]
VORT_ACC2_anticyc = ds_ACC2_anticyc.composite[1,:,:]

ds_ACC2_cyc_swot_like = xr.open_dataset(path_in + 'composite_swot_like_ACC2_cyclonic_biharmonic.nc')
ds_ACC2_anticyc_swot_like = xr.open_dataset(path_in + 'composite_swot_like_ACC2_anticyclonic_biharmonic.nc')


KE_ACC2_cyc_swot_like = ds_ACC2_cyc_swot_like.composite[0,:,:]
KE_ACC2_anticyc_swot_like = ds_ACC2_anticyc_swot_like.composite[0,:,:]



# ###########
# # --- MED
# ###########
ds_MED_cyc = xr.open_dataset(path_in + 'composite_swot_MED_cyclonic_biharmonic.nc')
ds_MED_anticyc = xr.open_dataset(path_in + 'composite_swot_MED_anticyclonic_biharmonic.nc')
KE_MED_cyc = ds_MED_cyc.composite[0,:,:]
KE_MED_anticyc = ds_MED_anticyc.composite[0,:,:]



ds_MED_cyc_swot_like = xr.open_dataset(path_in + 'composite_swot_like_MED_cyclonic_biharmonic.nc')
ds_MED_anticyc_swot_like = xr.open_dataset(path_in + 'composite_swot_like_MED_anticyclonic_biharmonic.nc')


KE_MED_cyc_swot_like = ds_MED_cyc_swot_like.composite[0,:,:]
KE_MED_anticyc_swot_like = ds_MED_anticyc_swot_like.composite[0,:,:]

# %%
props = dict(boxstyle='round', facecolor='w')

# %%
fig, axes = plt.subplots(ncols = 6, nrows = 4, sharex = True, sharey = True)
vmin = 0
vmax = .1
nb_quiver = 33
ax = axes[0][0]

ax.set_title('Gulf\nStream')
vmin = 0
vmax = .18
p1 = plot_composite(ax, KE_GS_cyc, vmin, vmax, 'RdYlBu_r')
ax.text(0.55, 0.1, perc_cyc[0],
     transform = ax.transAxes, bbox = props, color = 'tomato', fontsize = 8)

ax = axes[1][0]
_ = plot_composite(ax, KE_GS_cyc_swot_like, vmin, vmax, 'RdYlBu_r')

ax = axes[2][0]
_ = plot_composite(ax, KE_GS_anticyc, vmin, vmax, 'RdYlBu_r')
ax.text(0.45, 0.1, perc_anticy[0],
     transform = ax.transAxes, bbox = props, color = 'teal', fontsize = 8)

ax = axes[3][0]
_ = plot_composite(ax, KE_GS_anticyc_swot_like, vmin, vmax, 'RdYlBu_r')

cax = fig.add_axes([.125, -.08, .1, 0.015])
cbar = plt.colorbar(p1, cax = cax, orientation = 'horizontal', ticks = [vmin, (vmin+vmax)/2, vmax])
cbar.ax.xaxis.set_major_formatter(mticker.FormatStrFormatter('%.2f'))

cbar.ax.tick_params(rotation=45)

ax = axes[0][1]
vmin = 0
vmax = 0.18
ax.set_title('Agulhas')
p1 = plot_composite(ax, KE_AGULHAS_cyc, vmin, vmax, 'RdYlBu_r')
ax.text(0.6, 0.1, perc_cyc[1],
     transform = ax.transAxes, bbox = props, color = 'tomato', fontsize = 8)

ax = axes[1][1]
_ = plot_composite(ax, KE_AGUHAS_cyc_swot_like, vmin, vmax, 'RdYlBu_r')


ax = axes[2][1]
_ = plot_composite(ax, KE_AGULHAS_anticyc, vmin, vmax, 'RdYlBu_r')
ax.text(0.45, 0.1, perc_anticy[1],
     transform = ax.transAxes, bbox = props, color = 'teal', fontsize = 8)

ax = axes[3][1]
_ = plot_composite(ax, KE_AGUHAS_anticyc_swot_like, vmin, vmax, 'RdYlBu_r')


cax = fig.add_axes([.265, -.08, .1, 0.015])

cbar = plt.colorbar(p1, cax = cax, orientation = 'horizontal', ticks = [vmin, (vmin+vmax)/2, vmax])
cbar.ax.xaxis.set_major_formatter(mticker.FormatStrFormatter('%.2f'))
cbar.ax.tick_params(rotation=45)


ax = axes[0][2]
vmin = 0.0
vmax = 0.04
ax.set_title('CCS')
# ax.pcolormesh(ds_GS2_DUACS_cyclonic.x, ds_GS2_DUACS_cyclonic.y, uspeed_GS2_cyclonic, vmin = 0, vmax = .4)
p1= plot_composite(ax, KE_CCS_cyc, vmin, vmax, 'RdYlBu_r')
ax.text(0.45, 0.1, perc_cyc[2],
     transform = ax.transAxes, bbox = props, color = 'tomato', fontsize = 8)

ax = axes[1][2]
_ = plot_composite(ax, KE_CCS_cyc_swot_like, vmin, vmax, 'RdYlBu_r')

ax = axes[2][2]
_ = plot_composite(ax, KE_CCS_anticyc, vmin, vmax, 'RdYlBu_r')
ax.text(0.45, 0.1, perc_anticy[2],
     transform = ax.transAxes, bbox = props, color = 'teal', fontsize = 8)

ax = axes[3][2]
_ = plot_composite(ax, KE_CCS_anticyc_swot_like, vmin, vmax, 'RdYlBu_r')

cax = fig.add_axes([.395, -.08, .1, 0.015])

cbar = plt.colorbar(p1, cax = cax, orientation = 'horizontal', ticks = [vmin, (vmin+vmax)/2, vmax])
cbar.ax.xaxis.set_major_formatter(mticker.FormatStrFormatter('%.2f'))
cbar.ax.tick_params(rotation=45)



ax = axes[0][3]
vmin = 0.0
vmax = 0.12
ax.set_title('ACC1')
# ax.pcolormesh(ds_GS2_DUACS_cyclonic.x, ds_GS2_DUACS_cyclonic.y, uspeed_GS2_cyclonic, vmin = 0, vmax = .4)
p1 = plot_composite(ax, KE_ACC1_cyc, vmin, vmax, 'RdYlBu_r')
ax.text(0.6, 0.1, perc_cyc[3],
     transform = ax.transAxes, bbox = props, color = 'tomato', fontsize = 8)

ax = axes[1][3]
_ = plot_composite(ax, KE_ACC1_cyc_swot_like, vmin, vmax, 'RdYlBu_r')

ax = axes[2][3]
_ = plot_composite(ax, KE_ACC1_anticyc, vmin, vmax, 'RdYlBu_r')
ax.text(0.55, 0.1, perc_anticy[3],
     transform = ax.transAxes, bbox = props, color = 'teal', fontsize = 8)


ax = axes[3][3]
_ = plot_composite(ax, KE_ACC1_anticyc_swot_like, vmin, vmax, 'RdYlBu_r')


cax = fig.add_axes([.53, -.08, .1, 0.015])

cbar = plt.colorbar(p1, cax = cax, orientation = 'horizontal', ticks = [vmin, (vmin+vmax)/2, vmax])
cbar.ax.xaxis.set_major_formatter(mticker.FormatStrFormatter('%.2f'))
cbar.ax.tick_params(rotation=45)


ax = axes[0][4]
vmin = 0.0
vmax = 0.06
ax.set_title('ACC2')
# ax.pcolormesh(ds_GS2_DUACS_cyclonic.x, ds_GS2_DUACS_cyclonic.y, uspeed_GS2_cyclonic, vmin = 0, vmax = .4)
p1 = plot_composite(ax, KE_ACC2_cyc,  vmin, vmax,  'RdYlBu_r')
ax.text(0.55, 0.1, perc_cyc[4],
     transform = ax.transAxes, bbox = props, color = 'tomato', fontsize = 8)

ax = axes[1][4]
_ = plot_composite(ax, KE_ACC2_cyc_swot_like,  vmin, vmax,  'RdYlBu_r')


ax = axes[2][4]
_ = plot_composite(ax, KE_ACC2_anticyc,  vmin, vmax,  'RdYlBu_r')
ax.text(0.45, 0.1, perc_anticy[4],
     transform = ax.transAxes, bbox = props, color = 'teal', fontsize = 8)


ax = axes[3][4]
_ = plot_composite(ax, KE_ACC2_anticyc_swot_like, vmin, vmax,  'RdYlBu_r')



cax = fig.add_axes([.66, -.08, .1, 0.015])

cbar = plt.colorbar(p1, cax = cax, orientation = 'horizontal', ticks = [vmin, (vmin+vmax)/2, vmax])

cbar.ax.xaxis.set_major_formatter(mticker.FormatStrFormatter('%.2f'))
cbar.ax.tick_params(rotation=45)


ax = axes[0][5]
vmin = 0.0
vmax = 0.03
ax.set_title('MED')
# ax.pcolormesh(ds_GS2_DUACS_cyclonic.x, ds_GS2_DUACS_cyclonic.y, uspeed_GS2_cyclonic, vmin = 0, vmax = .4)
p1 = plot_composite(ax, KE_MED_cyc,  vmin, vmax,  'RdYlBu_r')
ax.text(0.45, 0.1, perc_cyc[5],
     transform = ax.transAxes, bbox = props, color = 'tomato', fontsize = 8)


ax = axes[1][5]
_ = plot_composite(ax, KE_MED_cyc_swot_like,  vmin, vmax,  'RdYlBu_r')


ax = axes[2][5]
_ = plot_composite(ax, KE_MED_anticyc,  vmin, vmax,  'RdYlBu_r')
ax.text(0.45, 0.1, perc_anticy[5],
     transform = ax.transAxes, bbox = props, color = 'teal', fontsize = 8)


ax = axes[3][5]
_ = plot_composite(ax, KE_MED_anticyc_swot_like, vmin, vmax,  'RdYlBu_r')




cax = fig.add_axes([.79, -.08, .1, 0.015])

cbar = plt.colorbar(p1, cax = cax, orientation = 'horizontal', ticks = [vmin, (vmin+vmax)/2, vmax])
cbar.ax.xaxis.set_major_formatter(mticker.FormatStrFormatter('%.2f'))

# cbar.ax.set_xticklabels(clevs1[::1] rotation=90)
cbar.ax.tick_params(rotation=45)
# cbar.ax.set_title('Current speed [m/s]')
ax.text(-17, -.1, 'SWOT-like')
ax.text(-17, 2.4, 'SWOT')
ax.text(-17, 4.7, 'SWOT-like')
ax.text(-17, 7.2, 'SWOT')
ax.text(1.5, 0, 'Anticyclonic', rotation = 90, fontsize = 14)
ax.text(1.5, 5.3, 'Cyclonic', rotation = 90, fontsize = 14)
ax.text(-8.8, -5.1, 'Kinetic Energy [m$^{2}$/s$^{2}$]', fontsize = 12)
plt.savefig(path_output +'Fig2.png', dpi = 300, bbox_inches = 'tight')
