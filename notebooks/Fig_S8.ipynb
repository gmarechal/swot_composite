# %%
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np

# %%
path_input = '../data/'
path_output = '../figures/'

# %%
ds_GS = xr.open_dataset(path_input + 'Gulf_stream_data_FigS8.nc')
ds_AGULHAS = xr.open_dataset(path_input + 'AGULHAS_data_FigS8.nc')
ds_CCS = xr.open_dataset(path_input + 'CCS_data_FigS8.nc')
ds_ACC1 = xr.open_dataset(path_input + 'ACC1_data_FigS8.nc')
ds_ACC2 = xr.open_dataset(path_input + 'ACC2_data_FigS8.nc')
ds_MED = xr.open_dataset(path_input + 'MED_data_FigS8.nc')

# %%
ds.rmax_swot
# Out:
# <xarray.DataArray 'rmax_swot' (eddies: 396)>
# array([0.009988, 0.010343, 0.00695 , ..., 0.012615, 0.012846, 0.008063],
#       dtype=float32)
# Coordinates:
#   * eddies   (eddies) int64 0 1 2 3 4 5 6 7 ... 388 389 390 391 392 393 394 395

# %%
fig, axes = plt.subplots(ncols = 5, nrows = 2, figsize = (15, 5))
ax = axes[0][0]
ds = ds_AGULHAS.copy()
ax.plot(ds.eke_swot, ds.eke_duacs, marker = 'x', lw = 0, color = 'k', alpha = .3)
ax.errorbar(ds.bin_eke, ds.mean_eke, yerr = ds.std_eke, capsize = 5, color = 'teal')
ax.plot([0, np.amax(ds_AGULHAS.bin_eke)], [0, np.amax(ds.bin_eke)], color = 'navy')
ax.set_xlim([0, np.amax(ds.bin_eke)])
ax.set_ylim([0, np.amax(ds.bin_eke)])
ax.set_aspect('equal', 'box')
ax.set_xlabel('EKE SWOT [$m^{2}/s^{2}$]')
ax.set_ylabel('EKE\nSWOT-like [$m^{2}/s^{2}$]')
s1 = ax.scatter(ds.bin_eke, ds.mean_eke, c = ds.mean_rmax_per_eke, vmin = 10, vmax = 50, cmap = 'Oranges', zorder = 10)
cax = fig.add_axes([.1, 1.1, 0.1, .015])
plt.colorbar(s1, label = '$R_{max}$ SWOT [km]', cax = cax, orientation = 'horizontal')

ax.grid()

# ax.text(0.06, 0.88, '(i)',
#      transform = ax.transAxes, bbox = props)


ax = axes[1][0]


ax.plot(ds.rmax_swot, ds.rmax_duacs, marker = 'x', lw = 0, color = 'k', alpha = .3)
ax.errorbar(ds.bin_rmax, ds.mean_rmax, yerr = ds.std_rmax, capsize = 5, color = 'teal')


ax.plot([0, np.amax(ds.bin_rmax)], [0, np.amax(ds.bin_rmax)], color = 'navy')

ax.set_xlim([0, np.amax(ds.bin_rmax)])
ax.set_ylim([0, np.amax(ds.bin_rmax)])
    # ax.set_aspect('equal', 'box')
ax.set_xlabel('R$_{max}$ SWOT [km]')
ax.set_ylabel('R$_{max}$ SWOT-like\n[km]')
ax.set_aspect('equal', 'box')

ax.grid()


ax.legend(frameon=False, fontsize = 8, bbox_to_anchor=(0.49, 0.82))


ax = axes[0][1]
ds = ds_CCS.copy()
ax.plot(ds.eke_swot, ds.eke_duacs, marker = 'x', lw = 0, color = 'k', alpha = .3)
ax.errorbar(ds.bin_eke, ds.mean_eke, yerr = ds.std_eke, capsize = 5, color = 'teal')
ax.plot([0, np.amax(ds.bin_eke)], [0, np.amax(ds.bin_eke)], color = 'navy')
ax.set_xlim([0, np.amax(ds.bin_eke)])
ax.set_ylim([0, np.amax(ds.bin_eke)])
ax.set_aspect('equal', 'box')
s1 = ax.scatter(ds.bin_eke, ds.mean_eke, c = ds.mean_rmax_per_eke, vmin = 10, vmax = 30, cmap = 'Oranges', zorder = 10)
cax = fig.add_axes([.29, 1.1, 0.1, .015])
plt.colorbar(s1, label = '$R_{max}$ SWOT [km]', cax = cax, orientation = 'horizontal')
ax.set_xlabel('EKE SWOT [$m^{2}/s^{2}$]')

ax.grid()

# ax.text(0.06, 0.88, '(i)',
#      transform = ax.transAxes, bbox = props)


ax = axes[1][1]


ax.plot(ds.rmax_swot, ds.rmax_duacs, marker = 'x', lw = 0, color = 'k', alpha = .3)
ax.errorbar(ds.bin_rmax, ds.mean_rmax, yerr = ds.std_rmax, capsize = 5, color = 'teal')


ax.plot([0, np.amax(ds.bin_rmax)], [0, np.amax(ds.bin_rmax)], color = 'navy')

ax.set_xlim([0, np.amax(ds.bin_rmax)])
ax.set_ylim([0, np.amax(ds.bin_rmax)])
    # ax.set_aspect('equal', 'box')
ax.set_xlabel('R$_{max}$ SWOT [km]')
ax.set_aspect('equal', 'box')

ax.grid()


ax = axes[0][2]
ds = ds_ACC1.copy()
ax.plot(ds.eke_swot, ds.eke_duacs, marker = 'x', lw = 0, color = 'k', alpha = .3)
ax.errorbar(ds.bin_eke, ds.mean_eke, yerr = ds.std_eke, capsize = 5, color = 'teal')
ax.plot([0, np.amax(ds.bin_eke)], [0, np.amax(ds.bin_eke)], color = 'navy')
ax.set_xlim([0, np.amax(ds.bin_eke)])
ax.set_ylim([0, np.amax(ds.bin_eke)])
ax.set_aspect('equal', 'box')
s1 = ax.scatter(ds.bin_eke, ds.mean_eke, c = ds.mean_rmax_per_eke, vmin = 10, vmax = 40, cmap = 'Oranges', zorder = 10)
cax = fig.add_axes([.47, 1.1, 0.1, .015])
plt.colorbar(s1, label = '$R_{max}$ SWOT [km]', cax = cax, orientation = 'horizontal')

ax.grid()

# ax.text(0.06, 0.88, '(i)',
#      transform = ax.transAxes, bbox = props)
ax.set_xlabel('EKE SWOT [$m^{2}/s^{2}$]')


ax = axes[1][2]


ax.plot(ds.rmax_swot, ds.rmax_duacs, marker = 'x', lw = 0, color = 'k', alpha = .3)
ax.errorbar(ds.bin_rmax, ds.mean_rmax, yerr = ds.std_rmax, capsize = 5, color = 'teal')


ax.plot([0, np.amax(ds.bin_rmax)], [0, np.amax(ds.bin_rmax)], color = 'navy')

ax.set_xlim([0, np.amax(ds.bin_rmax)])
ax.set_ylim([0, np.amax(ds.bin_rmax)])
    # ax.set_aspect('equal', 'box')
ax.set_xlabel('R$_{max}$ SWOT [km]')
ax.set_aspect('equal', 'box')
ax.grid('on')


ax = axes[0][3]
ds = ds_ACC2.copy()
ax.plot(ds.eke_swot, ds.eke_duacs, marker = 'x', lw = 0, color = 'k', alpha = .3)
ax.errorbar(ds.bin_eke, ds.mean_eke, yerr = ds.std_eke, capsize = 5, color = 'teal')
ax.plot([0, np.amax(ds.bin_eke)], [0, np.amax(ds.bin_eke)], color = 'navy')
ax.set_xlim([0, np.amax(ds.bin_eke)])
ax.set_ylim([0, np.amax(ds.bin_eke)])
ax.set_aspect('equal', 'box')
s1 = ax.scatter(ds.bin_eke, ds.mean_eke, c = ds.mean_rmax_per_eke, vmin = 10, vmax = 40, cmap = 'Oranges', zorder = 10)
cax = fig.add_axes([.66, 1.1, 0.1, .015])
plt.colorbar(s1, label = '$R_{max}$ SWOT [km]', cax = cax, orientation = 'horizontal')

ax.grid('on')

# ax.text(0.06, 0.88, '(i)',
#      transform = ax.transAxes, bbox = props)

ax.set_xlabel('EKE SWOT [$m^{2}/s^{2}$]')

ax = axes[1][3]


ax.plot(ds.rmax_swot, ds.rmax_duacs, marker = 'x', lw = 0, color = 'k', alpha = .3)
ax.errorbar(ds.bin_rmax, ds.mean_rmax, yerr = ds.std_rmax, capsize = 5, color = 'teal')


ax.plot([0, np.amax(ds.bin_rmax)], [0, np.amax(ds.bin_rmax)], color = 'navy')

ax.set_xlim([0, np.amax(ds.bin_rmax)])
ax.set_ylim([0, np.amax(ds.bin_rmax)])
    # ax.set_aspect('equal', 'box')
ax.set_xlabel('R$_{max}$ SWOT [km]')
ax.set_aspect('equal', 'box')
ax.grid('on')


ax = axes[0][4]
ds = ds_MED.copy()
ax.plot(ds.eke_swot, ds.eke_duacs, marker = 'x', lw = 0, color = 'k', alpha = .3)
ax.errorbar(ds.bin_eke, ds.mean_eke, yerr = ds.std_eke, capsize = 5, color = 'teal')
ax.plot([0, np.amax(ds.bin_eke)], [0, np.amax(ds.bin_eke)], color = 'navy')
ax.set_xlim([0, np.amax(ds.bin_eke)])
ax.set_ylim([0, np.amax(ds.bin_eke)])
ax.set_aspect('equal', 'box')
s1 = ax.scatter(ds.bin_eke, ds.mean_eke, c = ds.mean_rmax_per_eke, vmin = 10, vmax = 30, cmap = 'Oranges', zorder = 10)
cax = fig.add_axes([.85, 1.1, 0.1, .015])
plt.colorbar(s1, label = '$R_{max}$ SWOT [km]', cax = cax, orientation = 'horizontal')

ax.grid('on')

# ax.text(0.06, 0.88, '(i)',
#      transform = ax.transAxes, bbox = props)

ax.set_xlabel('EKE SWOT [$m^{2}/s^{2}$]')

ax = axes[1][4]


ax.plot(ds.rmax_swot, ds.rmax_duacs, marker = 'x', lw = 0, color = 'k', alpha = .3)
ax.errorbar(ds.bin_rmax, ds.mean_rmax, yerr = ds.std_rmax, capsize = 5, color = 'teal')


ax.plot([0, np.amax(ds.bin_rmax)], [0, np.amax(ds.bin_rmax)], color = 'navy')

ax.set_xlim([0, np.amax(ds.bin_rmax)])
ax.set_ylim([0, np.amax(ds.bin_rmax)])
    # ax.set_aspect('equal', 'box')
ax.set_xlabel('R$_{max}$ SWOT [km]')
ax.set_aspect('equal', 'box')

ax.grid('on')


plt.tight_layout()
plt.savefig(path_output + 'Fig_S8', dpi = 300, bbox_inches = 'tight')
# Out:
# /var/folders/bx/gz6w8d_533x2h1m1pq2pt88m0000gn/T/ipykernel_52496/98113479.py:41: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(frameon=False, fontsize = 8, bbox_to_anchor=(0.49, 0.82))
# /var/folders/bx/gz6w8d_533x2h1m1pq2pt88m0000gn/T/ipykernel_52496/98113479.py:190: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
